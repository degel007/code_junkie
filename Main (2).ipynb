# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %matplotlib inline



import pandas as pd
import numpy as np
import os
import csv
import tui




def collect_file_path():
    
    cs = input('Please, enter file path: ')
    while cs != 'Car_Price.csv':
        print('Invalid file path! Program not designed to work with input. Try again')
        cs = input('Please, enter file path: ')
    else:
        tui.started(f"Reading data from {cs}")
        df_car_sales = pd.read_csv(f'{cs}')
            
    tui.completed
    

df_car_sales = collect_file_path()   



def run():
    df_car_sales = pd.read_csv('Car_Price.csv')
    while True:
        selection = tui.menu()
        if selection == "1":
            from Retrieve import retrieve_by_card_ID
            retrieve_by_card_ID()
        elif selection == "2":
            from Retrieve import cars_by_cylindernumber
            cars_by_cylindernumber()
        elif selection == "3":
            from Retrieve import name_by_carbody
            name_by_carbody()
        elif selection == "4":
            from Retrieve import retrieve_4col_by_id
            retrieve_4col_by_id()
        elif selection == "5":
            from Query import query_by_alpha
            query_by_alpha()
        elif selection == "6":
            from Query import total_sales_by_carbody
            total_sales_by_carbody()
        elif selection == "7":
            from Query import price_per_carbody
            price_per_carbody()
        elif selection == "8":
            from Query import get_highway_mileage
            get_highway_mileage()
        elif selection == "9":
            from Visuals import cs_visuals_1
            cs_visuals_1()
        elif selection == "10":
            from Visuals import cs_visuals_2
            cs_visuals_2()
        elif selection == "11":
            from Visuals import sales_percentage_by_carbody
            sales_percentage_by_carbody()
        elif selection == "exit":
            break
    
        else:
            tui.error("Invalid Selection!")


if __name__ == "__main__":
    run()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Please, enter file path: carp
# Invalid file path! Program not designed to work with input. Try again
# Please, enter file path: Car_Price.csv
# -------------------------------------------------------------------------------------
# Operation started: Reading data from Car_Price.csv...
#
# Please select one of the following options:
#     [1]        Retrieve a record for an individual car by ID
#     [2]        Retrieve all cars for a specified Cylinder Number
#     [3]        Retrieve all cars by the specified Car Body
#     [4]        Specifications by ID, showing Car Name, Cylinder Number, Door Number, and Car body
#     [5]        Retrieve carnames alphabetically
#     [6]        Retrieve summary of sales (total car price) for each car body
#     [7]        Retrieve the top 5 car sale by price (the most expensive) and per car body
# ...
